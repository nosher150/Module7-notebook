# %% [markdown]
# <a href="https://colab.research.google.com/github/nosher150/Module7-notebook/blob/main/Copy_of_Exploration_Task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exploration Task
#
# The data you are going to be using for this activity is information on different cars. We will be using this dataset in the workshop, but it is not in a currently usable format. Follow the steps below to inspect the dataset. We will clean it together during the first workshop.<br><br>
#
# The dataset conatins various information about the cars which include:<br>
#
# <ul>
#     <li> <b>index</b>: index of dataframe </li>
#     <li> <b>car</b>: car manufacturer </li>
#     <li> <b>model</b>: model of car </li>
#     <li> <b>mpg</b>: miles per gallon </li>
#     <li> <b>cyl</b>: number of cylinders </li>
#     <li> <b>disp</b>: displacement in cubic inches </li>
#     <li> <b>hp</b>: gross horsepower </li>
#     <li> <b>drat</b>: rear axle ratio </li>
#     <li> <b>wt</b>: weight in pounds </li>
#     <li> <b>qsec</b>: quarter mile time </li>
#     <li> <b>vs</b>: engine (0=V-shaped, 1= straight) </li>
#     <li> <b>am</b>: transmission (0 =automatic, 1=manual) </li>
#     <li> <b>gear</b>: number of forward gears </li>
#     <li> <b>carb</b>: number of carburetors </li>
#     <li> <b>color</b>: car color </li>
# </ul>

# %%
#import pands

import pandas as pd

# %%
# import the data

cars=pd.read_csv('cars_features.csv')

print(cars.shape)

cars.head()
# Out:
# (63, 17)
#    index     car       model   mpg  cyl   disp     hp  drat         wt   qsec  \
# 0      0   Mazda         RX4  21.0  6.0  160.0  110.0  3.90   2.62 lbs  16.46
# 1      1   Mazda         RX4  21.0  6.0  160.0  110.0  3.90  2.875 lbs  17.02
# 2      2  Datsun         710  22.8  4.0  108.0   93.0  3.85   2.32 lbs  18.61
# 3      3  Hornet           4  21.4  6.0  258.0  110.0  3.08  3.215 lbs  19.44
# 4      4  harnet  Sportabout  18.7  8.0  360.0  175.0  3.15   3.44 lbs  17.02
#
#     vs   am  gear  carb     model.1  color   code
# 0  NaN  1.0   4.0   4.0         RX4    NaN  NK407
# 1  NaN  1.0   4.0   4.0         RX4    NaN  CM144
# 2  1.0  1.0   4.0   1.0         710    NaN  PA489
# 3  1.0  0.0   3.0   1.0           4    NaN  QT333
# 4  NaN  0.0   3.0   2.0  Sportabout    NaN  GE476

# %% [markdown]
# ### Inspect the Data

# %%
# Use .info() to check each columns data type and for the number of nulls
# Are any columns looking like a concern?

#A: cars.info()

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 17 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   index    63 non-null     int64
#  1   car      51 non-null     object
#  2   model    48 non-null     object
#  3   mpg      51 non-null     float64
#  4   cyl      51 non-null     float64
#  5   disp     51 non-null     float64
#  6   hp       51 non-null     float64
#  7   drat     51 non-null     float64
#  8   wt       53 non-null     object
#  9   qsec     51 non-null     float64
#  10  vs       24 non-null     float64
#  11  am       51 non-null     float64
#  12  gear     51 non-null     float64
#  13  carb     51 non-null     float64
#  14  model.1  48 non-null     object
#  15  color    0 non-null      float64
#  16  code     53 non-null     object
# dtypes: float64(11), int64(1), object(5)
# memory usage: 8.5+ KB

# %%
# Use .describe() to view summary statistics for each numeric column

#A:Color is empty/ model and model.1 share the same name. wt contains both numbers and text.

# %%
cars.describe()
# Out:
#            index        mpg        cyl        disp          hp       drat  \
# count  63.000000  51.000000  51.000000   51.000000   51.000000  51.000000
# mean   31.000000  19.898039   6.196078  234.890196  143.254902   3.532353
# std    18.330303   5.402203   1.755216  119.582867   62.276109   0.497741
# min     0.000000  10.400000   4.000000   71.100000   52.000000   2.760000
# 25%    15.500000  16.850000   4.000000  140.800000   97.000000   3.080000
# 50%    31.000000  19.200000   6.000000  225.000000  123.000000   3.690000
# 75%    46.500000  22.150000   8.000000  350.000000  180.000000   3.910000
# max    62.000000  33.900000   8.000000  472.000000  335.000000   4.930000
#
#             qsec    vs         am       gear       carb  color
# count  51.000000  24.0  51.000000  51.000000  51.000000    0.0
# mean   18.094314   1.0   0.294118   3.588235   2.666667    NaN
# std     1.809919   0.0   0.460179   0.697896   1.451436    NaN
# ...

# %%
# Which columns would you say are categorical data?
# For each one, identify what the different options are.

#A:

# %%
c = cars.categorical()
print(c)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-d0c6325c42d6> in <module>
# ----> 1 c = cars.categorical()
#       2 print(c)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'categorical'

# %%
# What is the most common number of forward gears?

#A:3 forward gears

# %%
cars.groupby(['gear']).aggregate({'gear': ['mean', 'median', 'count']})
# Out:
#      gear
#      mean median count
# gear
# 3.0   3.0    3.0    27
# 4.0   4.0    4.0    18
# 5.0   5.0    5.0     6

# %%
# How many duplicate rows exist in this dataset?

#A:0 (?)

# %%
cars.duplicated(keep=False).sum()
# Out:
# 0
